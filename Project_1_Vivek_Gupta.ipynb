# %% [markdown]
# **Problem Statement**

# %%
#Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Uploading file from Google drive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

#Authenticate and create the PyDrive client
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

link = 'https://drive.google.com/file/d/1WmiFSwYOezQKDTYJ1PdpJNVJAc9eJbca/view?usp=sharing'

#to get the id part of the file
id = link.split("/")[-2]

download = drive.CreateFile({'id':id})
download.GetContentFile('Ecommerce Customers.csv')

# %%
#Creating Data Frame
df = pd.DataFrame(pd.read_csv('Ecommerce Customers.csv'))

# %%
#Data Checking
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df.tail()
# Out:
#                             Email  \
# 495  lewisjessica@craig-evans.com
# 496           katrina56@gmail.com
# 497            dale88@hotmail.com
# 498           cwilson@hotmail.com
# 499     hannahwilson@davidson.com
#
#                                                Address         Avatar  \
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...            Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320  PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...       Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...           Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...    DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# ...

# %%
df.shape
# Out:
# (500, 8)

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %% [markdown]
# **Exploratory Data Analysis**

# %%
#Checking Null Values
df.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
# Let's see how Sales are related with other variables using scatter plot.
sns.pairplot(df, x_vars=['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership'], y_vars='Yearly Amount Spent', height=4, aspect=1, kind='scatter')
plt.show()

# %%
#Checking for outliers
fig, axs = plt.subplots(5, figsize = (5,5))
plt1 = sns.boxplot(df['Avg. Session Length'], ax = axs[0])
plt2 = sns.boxplot(df['Time on App'], ax = axs[1])
plt3 = sns.boxplot(df['Time on Website'], ax = axs[2])
plt4 = sns.boxplot(df['Length of Membership'], ax = axs[3])
plt5 = sns.boxplot(df['Yearly Amount Spent'], ax = axs[4])
plt.tight_layout()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# **Dropping Outliers**

# %%
#Dropping outliers
def drop_outliers(train,columns):
    iqr=1.5*(np.percentile(train[columns],75) - np.percentile(train[columns],25))
    df.drop(train[train[columns]>(iqr+np.percentile(train[columns],75))].index,inplace=True)
    df.drop(train[train[columns]<(np.percentile(train[columns],25)-iqr)].index,inplace=True)

# %%
drop_outliers(df,"Length of Membership")
sns.boxplot(x="Length of Membership",data=df)

# %%
drop_outliers(df,"Avg. Session Length")
sns.boxplot(x="Avg. Session Length",data=df)

# %%
drop_outliers(df,"Time on App")
sns.boxplot(x="Time on App",data=df)

# %%
drop_outliers(df,"Time on Website")
sns.boxplot(x="Time on Website",data=df)

# %%
drop_outliers(df,"Yearly Amount Spent")
sns.boxplot(x="Yearly Amount Spent",data=df)

# %% [markdown]
# **Checking Co-relation and Co-variance**

# %%
df.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.038712        -0.006713
# Time on App                     -0.038712     1.000000         0.062489
# Time on Website                 -0.006713     0.062489         1.000000
# Length of Membership            -0.004891    -0.052907        -0.053616
# Yearly Amount Spent              0.332631     0.490521        -0.005112
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length              -0.004891             0.332631
# Time on App                      -0.052907             0.490521
# Time on Website                  -0.053616            -0.005112
# Length of Membership              1.000000             0.754071
# Yearly Amount Spent               0.754071             1.000000

# %%
df.cov()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              0.895077    -0.035103        -0.006334
# Time on App                     -0.035103     0.918608         0.059732
# Time on Website                 -0.006334     0.059732         0.994663
# Length of Membership            -0.004036    -0.044229        -0.046641
# Yearly Amount Spent             21.469820    32.074360        -0.347846
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length              -0.004036            21.469820
# Time on App                      -0.044229            32.074360
# Time on Website                  -0.046641            -0.347846
# Length of Membership              0.760792            44.872546
# Yearly Amount Spent              44.872546          4654.477383

# %% [markdown]
# **Dropping Unused Columns**

# %%
#Dropping columns
df = df.drop(['Email', 'Address', 'Avatar'], axis=1)
df
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
#      Yearly Amount Spent
# ...

# %% [markdown]
# **Dividing data columns**

# %%
## Selecting our target variable(dependent variable) and keeping the features aside (independent variable)
X = df.iloc[:, :-1]
y = df.iloc[:, 4]

# %%
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [471 rows x 4 columns]

# %% [markdown]
# **Creating Model** - Multiple Linear Regression

# %%
#Creating model

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %% [markdown]
# **Checking Performance**

# %%
#Checking performance
import sklearn.metrics as sm
sm.mean_absolute_error(y_test, y_pred)
# Out:
# 7.7169923644404035

# %%
sm.mean_squared_error(y_test,y_pred)
# Out:
# 94.00611164462444

# %%
np.sqrt(sm.mean_squared_error(y_test,y_pred))
# Out:
# 9.695674893715468

# %%
sm.r2_score(y_test,y_pred)
# Out:
# 0.9810536106419832

# %%
##EDA
sns.pairplot(df,hue='Yearly Amount Spent')

# %% [markdown]
# **Creating Model** - Single Linear Regression
# Using  - Avg. Session Length

# %%
#Creating model

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['Avg. Session Length'],y, test_size = 0.2, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
X_train = X_train.values.reshape(-1,1)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
X_test = X_test.values.reshape(-1,1)
y_pred = regressor.predict(X_test)

# %%
#Checking performance
import sklearn.metrics as sm
sm.mean_absolute_error(y_test, y_pred)
# Out:
# 55.0908273610174

# %%
sm.mean_squared_error(y_test,y_pred)
# Out:
# 4964.237325586198

# %%
sm.r2_score(y_test,y_pred)
# Out:
# 0.04072219499579666

# %% [markdown]
# **Creating Model** - Single Linear Regression Using - Time on App

# %%
#Creating model

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['Time on App'],y, test_size = 0.2, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
X_train = X_train.values.reshape(-1,1)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
X_test = X_test.values.reshape(-1,1)
y_pred = regressor.predict(X_test)

# %%
#Checking performance
import sklearn.metrics as sm
sm.mean_absolute_error(y_test, y_pred)
# Out:
# 48.310759201860215

# %%
sm.mean_squared_error(y_test,y_pred)
# Out:
# 3362.505236248293

# %%
sm.r2_score(y_test,y_pred)
# Out:
# 0.3502372205860418

# %% [markdown]
# **Creating Model** - Single Linear Regression Using - Time on Website

# %%
#Creating model

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['Time on Website'],y, test_size = 0.2, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
X_train = X_train.values.reshape(-1,1)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
X_test = X_test.values.reshape(-1,1)
y_pred = regressor.predict(X_test)

# %%
#Checking performance
import sklearn.metrics as sm
sm.mean_absolute_error(y_test, y_pred)
# Out:
# 57.34168263809232

# %%
sm.mean_squared_error(y_test,y_pred)
# Out:
# 5302.805806058516

# %%
sm.r2_score(y_test,y_pred)
# Out:
# -0.0247019995964195

# %% [markdown]
# **Creating Model** - Single Linear Regression Using - Length of Membership

# %%
#Creating model

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df['Length of Membership'],y, test_size = 0.2, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
X_train = X_train.values.reshape(-1,1)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
X_test = X_test.values.reshape(-1,1)
y_pred = regressor.predict(X_test)

# %%
#Checking performance
import sklearn.metrics as sm
sm.mean_absolute_error(y_test, y_pred)
# Out:
# 37.139845310931136

# %%
sm.mean_squared_error(y_test,y_pred)
# Out:
# 2085.93009843162

# %%
sm.r2_score(y_test,y_pred)
# Out:
# 0.5969196645973405
